# %%
import matplotlib.pyplot as plt
import pandas as pd
#import xlwings as xw

# %%
#create an empty workbook & rename sheet
#wb=xw.Book()
#sht=wb.sheets[0]
#sht.name="Python Charts"

# %%
#Helper function to insert 'Headings' into Excel cells
#def insert_heading(rng,text):
 #   rng.value=text
  #  rng.font.bold=True
   # rng.font.size=24
    #rng.font.color=(0,0,139)

# %%
#insert headings into excel sheet

# %%
#insert_heading(sht.range("A2"),"Matplotlib Chart")

# %%
x=[80,20]
y=["Deep learning","Machine learning"]
ex=[0.0,0.1]

c=["slateblue","darkslateblue"]
plt.pie(x,labels=y,colors=c,explode=ex,autopct="%0.1f%%",shadow=True,startangle=90)

plt.title("DATA SCIENTIST JOB-EXPECTATION",fontsize=15)
plt.legend(
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1,0.25, 0.5, 1))


fig=plt.show()

# %% [markdown]
# # Insert Chart into excel

# %%
#sht.pictures.add(
 #   fig,
  #  name="Matplotlib",
   # update=True,
    #left=sht.range("A4").left,
    #top=sht.range("A4").top,
    #height=200,
    #width=300,
#)

# %%
x=[30,20,10,10,10,20]
y=["Understanding  Problem","Maintenance","Machine/Deep Learning","Feature Engineering","Data Cleaning","Data Gathering"]

c=["slateblue","darkslateblue","mediumslateblue","mediumpurple","rebeccapurple","blueviolet"]

plt.pie(x,labels=y,colors=c,autopct="%0.1f%%",shadow=True,startangle=90)

plt.title("DATA SCIENTIST JOB-REALITY",fontsize=15)


plt.legend(
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1.25,0.5, 0.5, 1))

plt.show()
