# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [40 45 31 49 11 37 38 58 14 28 49 49 39 33 35 58 35 46 48 57 42 53 50 24
#  46 15 11 42 57 56 46 57 48 51 33 54 12 27 56 29 29 57 28 31 55 55 33 47
#  30 30]

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]

plt.hist(no,color="r",edgecolor="g")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %%
#we use ins taki data sahi s dikhe

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %%
#we use (0,200)to set range and always set this auto. Range parameter humesa 3rd no par put hoga and according to data we change

# %%
#the value of range function

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,"auto",(0,200),color="y",edgecolor="g")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %%
# cumulative function create the frequency of graph in reverse order

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",edgecolor="g",cumulative=-1)

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",bottom=10)

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %% [markdown]
# # Change HistoGraph Type

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",align="mid",histtype="step")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",align="mid",histtype="stepfilled")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",align="mid",histtype="barstacked")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",align="mid",histtype="bar")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %% [markdown]
# # Horizontal

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",orientation="horizontal")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",rwidth=0.5)

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %% [markdown]
# # Create log table

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",log=True)

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.show()

# %% [markdown]
# # ADD LABEL

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",label=("python"))

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)
         
plt.legend()
plt.show()

# %%
#Here we want to seperate the data ki jo kam ka hai vo ek side and dusra dusri side

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g",label="python")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.axvline(45,color="b",label="line")
plt.legend()
plt.show()

# %% [markdown]
# # Show grid

# %%
no=[40, 45, 31 ,49, 11 ,37, 38, 58 ,14 ,28, 49, 49, 39 ,33,35, 58 ,35, 46, 48 ,57, 42, 53 ,50,24,
 46 ,15 ,11 ,42 ,57 ,56, 46 ,57 ,48, 51, 33, 54 ,12, 27, 56, 29, 29, 57 ,28 ,31 ,55, 55, 33 ,47,
 30 ,30]
l=[10,20,30,40,50,60]

plt.hist(no,color="r",bins=l,edgecolor="g")

plt.title("wscube",fontsize=20)
plt.xlabel("Python",fontsize=20)
plt.ylabel("Number",fontsize=20)

plt.grid()
plt.show()
